# %%
#load yaml args file  "/home/g202516290/Documents/carbonateGPT/MiniGPT-Med/train_configs/minigptv2_finetune.yaml"
import yaml
from omegaconf import OmegaConf
with open("", 'r') as f:
    args = OmegaConf.create(yaml.safe_load(f))
from minigpt4.configs.config import Config  

cfg = Config(args)

# %%
import json
with open('/home/g202516290/Documents/carbonateGPT/carbonGPT.json', 'r') as f:
    data = json.load(f)
data[0]#['image_id']
# Out:
# {'image_path': 'Eugel_augmented/image_page695_1_aug000.jpg',
#  'caption': 'This thin section contains abundant, well-preserved tabulate corals (Alveolites – A), rugose corals (Tyrganolites – T), and stromatoporoids (Stachyodes – S, Clathrocoilona – C, Amphipora – AM). Larger growth cavities are filled with micritic clasts, peloids, and sparse microfossils forming a grainstone-packstone matrix, while remaining porosity is filled by blocky calcite cement.',
#  'image_id': 'image_page695_1_aug000'}

# %%
import yaml
from pprint import pprint

# Method 1: Load YAML file
with open('/home/g202516290/Documents/carbonateGPT/MiniGPT-Med/train_configs/minigptv2_finetune.yaml', 'r') as file:
    config = yaml.safe_load(file)

pprint(config)
# Out:
# {'datasets': {'grounding_SLAKE': {'batch_size': 6,
#                                   'text_processor': {'train': {'name': 'blip_caption'}},
#                                   'vis_processor': {'train': {'image_size': 448,
#                                                               'name': 'blip2_image_train'}}},
#               'identify_nlst': {'batch_size': 6,
#                                 'text_processor': {'train': {'name': 'blip_caption'}},
#                                 'vis_processor': {'train': {'image_size': 448,
#                                                             'name': 'blip2_image_train'}}},
#               'mimic_cxr': {'batch_size': 6,
#                             'text_processor': {'train': {'name': 'blip_caption'}},
#                             'vis_processor': {'train': {'image_size': 448,
#                                                         'name': 'blip2_image_train'}}},
#               'nlst': {'batch_size': 6,
# ...

# %%
import torch
import gc
torch.cuda.empty_cache()
gc.collect()
print("Cache cleared")
# Out:
# Cache cleared
